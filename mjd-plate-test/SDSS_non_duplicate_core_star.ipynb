# %%
import matplotlib.pyplot as plt
plt.style.use(['classic'])

import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
from astropy.io import fits

from scipy.stats import binned_statistic
from scipy.linalg import block_diag,eigh
plt.rcParams['font.family']='stixgeneral'
plt.rcParams.update({'font.size':16})
from astropy.io import fits
# Out:
# /Users/Jenny/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/Jenny/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/Jenny/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
sdss_core =  fits.open('sn_sdsscorestarsample.fits')

# %%
sdss_core[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                  104 / width of table in bytes
# NAXIS2  =                53463 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                   15 / number of columns
# EXTNAME = '/Users/Jenny/Downloads/MyTable_corestarbossplate2_jding.csv' / table
# TTYPE1  = 'snMedian_g'         / label for column 1
# TFORM1  = 'D       '           / format for column 1
# TTYPE2  = 'mjd     '           / label for column 2
# TFORM2  = 'J       '           / format for column 2
# TTYPE3  = 'plate   '           / label for column 3
# TFORM3  = 'I       '           / format for column 3
# TTYPE4  = 'fiberid '           / label for column 4
# TFORM4  = 'I       '           / format for column 4
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.get_xaxis().get_major_formatter().set_scientific(False)
n_bins = 50
ax.hist(sdss_core[1].data['snMedian_g'],bins=n_bins)
ax.set_ylabel('Number of stars')
ax.set_xlabel('S/N')
plt.savefig('test_sn_g_hist.png')
plt.xlim(0,40)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.get_xaxis().get_major_formatter().set_scientific(False)
n_bins = 50
ax.hist(sdss_core[1].data['psfmag_g'],bins=n_bins)
ax.set_xlabel('G_band Magnitude')
ax.set_ylabel('Number of stars')
plt.savefig('test_gband_hist.png')
#plt.xlim(0,40)
plt.show()
